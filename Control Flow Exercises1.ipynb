# %%
"""
Exercise 1
Guess a number between 1 to 9 given by the user
"""

import random

userNo = input("Tell me a number between 1 and 9")
userNo = int(userNo)
guessNo = random.randrange(1,9) #generate random number between 1 and 9

if guessNo == userNo:
    print("I knew it, it's",guessNo,"!")
else:
    print("It wasn't",guessNo,"well that sucks.")
    
"""
Exercise 2
Check the validity of password input by the user.

Validation:

At least 1 letter between [a-z] and 1 letter between [A-Z]
At least 1 number between [0-9]
At least 1 character from [$#@]
Minimum length 6 characters
Maximum length 16 characters
"""

specialChars = ["$","#","@"]


pasw=input("Enter password and I'll tell you how much it sucks")

if len(pasw) > 6: #check for length > 6
    if len(pasw) < 16: #check for lenght <16
        if any(char.isdigit() for char in pasw): #check if any numbers in password
            if any(substring in pasw for substring in specialChars): #check if any entries from special characters list in password
                if any(ele.isupper() for ele in pasw): #check if any uppercase letters in password
                    if any(ele.islower() for ele in pasw): #check if any lowercase letters in password
                        print("nice") #end state: all conditions met
                    else: print("Need a lowercase letter")
                else: print ("Need an uppercase letter")
            else: print("Need a special character")
        else: print("need a number, bruh")
    else: print("Too long")
else: print("Too short")
    
    
"""
Exercise 3
Get input of the age of 3 people by user and determine oldest and youngest among them
"""

p1 = input("Tell me the age of person 1")
p2 = input("Tell me the age of person 2")
p3 = input("Tell me the age of person 3")

p1=int(p1)
p2=int(p2)
p3=int(p3)

"""
Logic:
check if p1 older than p2, then if p1 older than p3. If yes to second argument, p1 oldest. If no to second argument, p3 oldest
if p2 older than p1, check if p2 older than p3. If yes to second argument, p2 oldest. If no to second argument, p3 oldest
"""

if p1>p2:
    if p1>p3: print("Person 1 is the oldest, at age",p1)
    else: print ("Person 3 is the oldest, at age",p3)
elif p2>p3: print('Person 2 is the oldest, at age',p2)
else: print("Person 3 is the oldest, at age",p3)

    
if p1<p2:
    if p1<p3: print("Person 1 is the youngest, at age",p1)
    else: print ("Person 3 is the youngest, at age",p3)
elif p2<p3: print('Person 2 is the youngest, at age',p2)
else: print("Person 3 is the youngest, at age",p3)
    
    
"""
Exercise 4
A student will not be allowed to sit in exam if his/her attendance is less than 75%.

Take following input from user

Number of classes held
Number of classes attended.
And print
percentage of class attended
Is student is allowed to sit in exam or not?
"""

held = input("How many classes have been held?")
attended = input("How many classes has student attended?")

percent=int(attended)/int(held)
print("Attendance ratio:",percent)

if percent>=0.75: print("Student is allowed to sit in exam")
else: print("Student is not allowed to sit in exam")
    
    
"""
Exercise 5

Get an integer N from the user and perform the following actions:

if N is odd, print "weird"
if N is even and in the inclusive range of 2 to 5, print "Not Weird"
if N is even and in the inclusive range of 6 to 20, print "Weird"
if N is even and greater than 20, print "Not Weird
"""

integ=input("Tell me an integer")
integ=int(integ)
print(integ)

#odd/even test: modulo. If remainder = 0, even. Else odd: (integ %2) != 0

if (integ %2) !=0: print("Weird")
elif (integ %2) == 0 and integ>=2 and integ<=5: print("not Weird")
elif (integ %2) == 0 and integ<=20 and integ>=6: print("Weird")
elif (integ %2) == 0 and integ>=20: print("not Weird")
else: print("Justin, what did you screw up") #put this here for myself in case the logic didn't work out somehow
# Out:
# Tell me a number between 1 and 95
# I knew it, it's 5 !
# Enter password and I'll tell you how much it sucksaaaaaaaaaaaa54#
# Need an uppercase letter
# Tell me the age of person 15
# Tell me the age of person 26
# Tell me the age of person 37
# Person 3 is the oldest, at age 7
# Person 1 is the youngest, at age 5
# How many classes have been held?9
# How many classes has student attended?99
# Attendance ratio: 11.0
# Student is allowed to sit in exam
# Tell me an integer5
# 5
# Weird
